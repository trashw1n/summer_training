# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mne
import os

# %%
def get_subject_folders(processed_path):
    folders = []
    for root, dirs, _ in os.walk(processed_path):
        folders.extend([os.path.join(root, d) for d in dirs]) 
        break # only top level subfolders required 
    return folders

folders = get_subject_folders(r'C:\Users\Ashwin\Desktop\processed')

# %%
template = {'mean_amp':[], 'mean_power':[], 'subject':[], 'is_PD':[]}
data = pd.DataFrame(template)

# %%
participants = pd.read_csv(r'C:\Users\Ashwin\Desktop\eeg\participants.tsv', sep= '\s+|\t+', engine='python')

# %%
data['subject'] = participants['participant_id'].copy()
data.set_index('subject', inplace=True, drop=True)

# %%
def categorize_label(row):
    if row['is_PD'] == 1:
        if row['MOCA'] < 22:
            return 'PDD'
        elif row['MOCA'] >= 22 and row['MOCA'] <= 26:
            return 'PD-MCI'
        else:
            return 'PD'
    else:
        return 'Control'

data['label'] = data.apply(categorize_label, axis=1)
data['MOCA'] = participants['MOCA'].values
data['Age'] = participants['AGE'].values
data['is_PD'] = participants['TYPE'].values

# %%
def get_avg_power(subject_path):
    epochs = mne.read_epochs(os.path.join(subject_path, subject_path[-7:] + '-epo.fif'))
    psd, freqs = mne.time_frequency.psd_array_multitaper(epochs['S  2'].pick('Cz').get_data(), fmin=1, fmax=10, n_jobs=1, verbose=None, sfreq=256)
    avg = psd.mean(axis=(0,2))[0]
    return avg

def get_avg_amplitude(subject_path):
    epochs = mne.read_epochs(os.path.join(subject_path, subject_path[-7:] + '-epo.fif'))
    return epochs['S  2'].pick('Cz').get_data().mean(axis=(0,2))[0]
    #return epochs.get_data().mean(axis=(0,2))

# %%
for subject in folders:
    data.loc[subject[-7:], 'mean_amp'] = get_avg_amplitude(subject)
    data.loc[subject[-7:], 'mean_power'] = get_avg_power(subject)
# Out:
# Reading C:\Users\Ashwin\Desktop\processed\sub-001\sub-001-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 323 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-001\sub-001-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 323 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-002\sub-002-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 419 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-002\sub-002-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 419 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-003\sub-003-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 441 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-003\sub-003-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 441 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-004\sub-004-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 382 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-004\sub-004-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 382 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-005\sub-005-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 691 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-005\sub-005-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 691 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-006\sub-006-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 282 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-006\sub-006-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 282 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-007\sub-007-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 98 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-007\sub-007-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 98 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-008\sub-008-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 572 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-008\sub-008-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 572 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-009\sub-009-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 597 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-009\sub-009-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 597 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-010\sub-010-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 186 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-010\sub-010-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 186 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-011\sub-011-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 19 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-011\sub-011-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 19 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-012\sub-012-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 573 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-012\sub-012-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 573 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-013\sub-013-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 517 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-013\sub-013-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 517 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-014\sub-014-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 134 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-014\sub-014-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 134 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-015\sub-015-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 341 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-015\sub-015-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 341 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-016\sub-016-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 709 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-016\sub-016-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 709 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-017\sub-017-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 609 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-017\sub-017-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 609 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-018\sub-018-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 143 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-018\sub-018-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 143 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-019\sub-019-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 261 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-019\sub-019-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 261 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-020\sub-020-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 51 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-020\sub-020-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 51 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-021\sub-021-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 588 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-021\sub-021-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 588 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-022\sub-022-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 71 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-022\sub-022-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 71 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-023\sub-023-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-023\sub-023-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-024\sub-024-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 714 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-024\sub-024-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 714 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-025\sub-025-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 196 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-025\sub-025-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 196 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-026\sub-026-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 20 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-026\sub-026-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 20 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-027\sub-027-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 12 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-027\sub-027-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 12 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-028\sub-028-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 157 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-028\sub-028-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 157 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-029\sub-029-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 707 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-029\sub-029-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 707 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-030\sub-030-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 496 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-030\sub-030-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 496 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-031\sub-031-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 551 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-031\sub-031-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 551 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-032\sub-032-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 397 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-032\sub-032-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 397 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-033\sub-033-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 94 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-033\sub-033-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 94 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-034\sub-034-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 474 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-034\sub-034-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 474 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-035\sub-035-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 136 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-035\sub-035-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 136 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-036\sub-036-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 492 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-036\sub-036-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 492 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-037\sub-037-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 396 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-037\sub-037-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 396 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-038\sub-038-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 131 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-038\sub-038-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 131 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-039\sub-039-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 204 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-039\sub-039-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 204 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-040\sub-040-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 456 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-040\sub-040-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 456 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-041\sub-041-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 400 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-041\sub-041-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 400 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-042\sub-042-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 545 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-042\sub-042-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 545 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-043\sub-043-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 625 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-043\sub-043-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 625 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-044\sub-044-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 584 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-044\sub-044-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 584 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-045\sub-045-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 237 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-045\sub-045-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 237 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-046\sub-046-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 670 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-046\sub-046-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 670 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-047\sub-047-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 211 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-047\sub-047-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 211 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-048\sub-048-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 36 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-048\sub-048-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 36 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-049\sub-049-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 512 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-049\sub-049-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 512 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-050\sub-050-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 155 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-050\sub-050-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 155 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-051\sub-051-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 690 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-051\sub-051-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 690 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-052\sub-052-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 372 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-052\sub-052-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 372 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-053\sub-053-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 360 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-053\sub-053-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 360 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-054\sub-054-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 445 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-054\sub-054-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 445 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-055\sub-055-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 338 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-055\sub-055-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 338 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-056\sub-056-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 564 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-056\sub-056-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 564 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-057\sub-057-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 570 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-057\sub-057-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 570 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-058\sub-058-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 294 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-058\sub-058-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 294 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-059\sub-059-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 161 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-059\sub-059-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 161 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-060\sub-060-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 99 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-060\sub-060-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 99 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-061\sub-061-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 53 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-061\sub-061-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 53 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-062\sub-062-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 397 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-062\sub-062-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 397 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-063\sub-063-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 637 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-063\sub-063-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 637 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-064\sub-064-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 454 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-064\sub-064-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 454 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-065\sub-065-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 17 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-065\sub-065-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 17 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-066\sub-066-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 341 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-066\sub-066-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 341 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-067\sub-067-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 674 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-067\sub-067-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 674 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-068\sub-068-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 456 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-068\sub-068-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 456 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-069\sub-069-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 712 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-069\sub-069-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 712 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-070\sub-070-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 481 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-070\sub-070-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 481 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-071\sub-071-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 698 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-071\sub-071-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 698 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-072\sub-072-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 35 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-072\sub-072-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 35 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-073\sub-073-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 695 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-073\sub-073-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 695 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-074\sub-074-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 623 matching events found
# No baseline correction applied
# 0 projection items activated
# ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 137 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-123\sub-123-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 469 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-123\sub-123-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 469 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-124\sub-124-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 252 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-124\sub-124-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 252 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-125\sub-125-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 688 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-125\sub-125-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 688 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-126\sub-126-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 24 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-126\sub-126-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 24 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-127\sub-127-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 682 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-127\sub-127-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 682 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-128\sub-128-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 509 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-128\sub-128-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 509 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-129\sub-129-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 223 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-129\sub-129-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 223 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-130\sub-130-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 481 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-130\sub-130-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 481 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-131\sub-131-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 408 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-131\sub-131-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 408 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-132\sub-132-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 623 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-132\sub-132-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 623 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-133\sub-133-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 599 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-133\sub-133-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 599 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-134\sub-134-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 89 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-134\sub-134-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 89 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-135\sub-135-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 552 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-135\sub-135-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 552 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-136\sub-136-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 62 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-136\sub-136-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 62 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-137\sub-137-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 279 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-137\sub-137-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 279 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-138\sub-138-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 51 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-138\sub-138-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 51 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-139\sub-139-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 695 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-139\sub-139-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 695 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-140\sub-140-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 201 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-140\sub-140-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 201 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-141\sub-141-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 50 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-141\sub-141-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 50 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-142\sub-142-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 312 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-142\sub-142-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 312 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-143\sub-143-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 256 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-143\sub-143-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 256 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-144\sub-144-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 412 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-144\sub-144-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 412 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-145\sub-145-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 719 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-145\sub-145-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 719 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Reading C:\Users\Ashwin\Desktop\processed\sub-146\sub-146-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 591 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading C:\Users\Ashwin\Desktop\processed\sub-146\sub-146-epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 591 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
#change X and y accordingly to select features and labels
X = data[(data['label']=='PD') | (data['label']=='PDD')][['mean_amp','mean_power','Age']]
y = data[(data['label']=='PD') | (data['label']=='PDD')]['label']

# %%
scaler.fit(X)
X_tr = scaler.transform(X)
# Out:
# StandardScaler()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_tr, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# Logistic Regression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
print("Accuracy score of logistic regression: ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy score of logistic regression:  0.7142857142857143

# %%
from sklearn.metrics import accuracy_score
#support vector machine
svc = SVC(kernel='linear')
svc.fit(X_train, y_train)
y_pred = svc.predict(X_test)
print("Accuracy score of SVM: ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy score of SVM:  0.6530612244897959

# %%
#random forest model
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

rf = RandomForestClassifier(n_estimators=200, max_depth=30, random_state=0)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6530612244897959

# %%
import pickle 
models = {'logistic_regression': logreg, 'svc': svc, 'random_forest': rf}
for model in models:
    with open(model + '.pkl', 'wb') as f:
        pickle.dump(models[model], f)
        print(f'{model} model succesfully saved')
# Out:
# logistic_regression model succesfully saved
# svc model succesfully saved
# random_forest model succesfully saved

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC


# Assuming X is your feature matrix and y is your target variable
X_train, X_test, y_train, y_test = train_test_split(X_tr, y, test_size=0.33, random_state=42)

# Define the number of folds (K)
k = 2
kf = KFold(n_splits=k)

# Initialize a list to store the evaluation scores for each fold
scores = []

for train_index, val_index in kf.split(X_train):
    X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

    # Train your model on X_train_fold and y_train_fold
    # Evaluate the model on X_val_fold and y_val_fold
    # For example, using a classifier (e.g., a decision tree)
    #svc = SVC(kernel='rbf')
    #rf = RandomForestClassifier(n_estimators=200, max_depth=30, random_state=0)
    logreg = LogisticRegression()
    logreg.fit(X_train_fold, y_train_fold)
    y_pred = logreg.predict(X_val_fold)
    
    # Calculate the accuracy score for this fold
    accuracy = accuracy_score(y_val_fold, y_pred)
    scores.append(accuracy)

# Calculate the mean and standard deviation of the accuracy scores
mean_accuracy = sum(scores) / k
std_deviation = np.std(scores)

print(f"Mean Accuracy: {mean_accuracy}")
print(f"Standard Deviation: {std_deviation}")
# Out:
# Mean Accuracy: 0.6764705882352942
# Standard Deviation: 0.02941176470588236
